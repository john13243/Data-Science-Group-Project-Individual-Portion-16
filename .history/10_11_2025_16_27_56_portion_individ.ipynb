# %% [markdown]
# Question 2: We would like to know which "kinds" of players are most likely to contribute a large amount of data so that we can target those players in our recruiting efforts. Thus, our question will be, what is the demographic of players that play Minecraft the most?
#
# To address this question, the kind of player that most likely contributes a large amount of data in Minecraft, will be answered with the data set: players.csv. First, we wll load in players.csv to look at the data, and then select which variables that will answer our question. The data will be assigned as "players_data."

# %%
library(tidyverse)

# %%
players_data <- read_csv("data/players.csv")
players_data

# %% [markdown]
# In players_data, there contains 196 total observations. Out of all the variables, the ones that can predict the demographic of a person that plays a lot of Minecraft are experience, played_hours, gender and age. The columns subscribe, email and name will be left out as these do not contribute to the demographic.
# - The experience variable is categorical and contains 5 possible values: "Beginner", "Amateur", "Regular", "Pro" and "Veteran". These placeholders describe the level of skill and experience each player has rated themselves from least to most experienced.
# - The played_hours variable is numeric and up to 1 decimal place. This variable, quantified in hours, was determined through how long each player played Minecraft in one sitting. This variable will be the response variable.
# - The gender variable is categorical and contains 3 options: "Male", "Female" and "Prefer not to say".
# - The age variable is numeric and contains integer values.
# A potential issue is that the gender variable contains the "Prefer not to say" option. As this data will not aide in the gender demographic relationship, it will not be considered. Another similar issue for the "Age" variable; observations with "NA" in its "Age" variable will also not be considered.
# This data was collected by a Computer Science research group at UBC led by Frank Wood. The method in which they collected data, was recording players' actions thoughout the world in their Minecraft servers.

# %% [markdown]
# including information such as the number of observations, summary statistics (report values to 2 decimal places), number of variables, name and type of variables, what the variables mean, any issues you see in the data, any other potential issues related to things you cannot directly see, how the data were collected, etc. Make sure to use bullet point lists or tables to summarize the variables in an easy-to-understand format.
